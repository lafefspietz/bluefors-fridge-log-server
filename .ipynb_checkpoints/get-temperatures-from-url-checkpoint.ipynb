# %%
import urllib.request
import json
with urllib.request.urlopen('http://67206fqe.campus.nist.gov/bluefors-fridge-log-server/4kplatetemp.json') as response:
   rawdata = response.read()
T_4k = json.loads(rawdata)

with urllib.request.urlopen('http://67206fqe.campus.nist.gov/bluefors-fridge-log-server/stilltemp.json') as response:
   rawdata = response.read()
T_still = json.loads(rawdata)

with urllib.request.urlopen('http://67206fqe.campus.nist.gov/bluefors-fridge-log-server/mxctemp2.json') as response:
   rawdata = response.read()
T_mc2 = json.loads(rawdata)

with urllib.request.urlopen('http://67206fqe.campus.nist.gov/bluefors-fridge-log-server/50kplatetemp.json') as response:
   rawdata = response.read()
T_50k = json.loads(rawdata)
T_4k
# Out:
# {'time': '15:00:06', 'temperature': 221.6844}

# %%
# Out:
# {'time': '14:31:36', 'temperature': '2.157285e+02'}
