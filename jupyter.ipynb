# %%
import matplotlib.pyplot as plt
import numpy as np
import skrf as rf

# %%
caldata = rf.read_all()

# %%
caldata
# Out:
# {'ideal_port2_load': 1-Port Network: 'ideal_port2_load',  0.001-20.0 GHz, 10001 pts, z0=[50.+0.j]}

# %%
x = np.linspace(0,10,100)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.savefig("plots/testplot.png")

# %% [markdown]
# # testplot.png:
# ![](plots/testplot.png)

# %%
x = np.linspace(-10,10,100)
y = x/np.tanh(x)
plt.plot(x,y)
plt.xlabel("eV/2kT")
plt.ylabel("normalized noise")
plt.xlim([-10,10])
plt.title('the normalized coth curve')
plt.ylim([0,10])
plt.grid()
plt.savefig("plots/cothfig.png")
